# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('./output/results.txt')
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Epoch    700 non-null    int64
#  1   Time(s)  700 non-null    float64
#  2   Loss     700 non-null    float64
#  3   F1       700 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 22.0 KB

# %%
results.columns
# Out:
# Index(['Epoch', 'Time(s)', 'Loss', 'F1'], dtype='object')

# %%
plt.plot(results['Epoch'],results['Loss'])
plt.xlabel('Epoch')        
plt.ylabel('Loss')   
plt.savefig('./output/loss.jpg')
plt.show()

# %%
plt.plot(results['Epoch'],results['F1'])
plt.xlabel('Epoch')        
plt.ylabel('F1 score')   
plt.savefig('./output/f1.jpg')
plt.show()

# %%
total_min = np.sum(results['Time(s)']) / 60
print('Time cost:', round(total_min,2), 'minutes.')
# Out:
# Time cost: 651.14 minutes.

# %%
# y-axis in log scale

plt.plot(results['Epoch'],results['Loss'])
plt.yscale('log')
plt.xlabel('Epoch')        
plt.ylabel('Loss')   
plt.show()
